# %% [markdown]
# # 1. Import librairies

# %%
pip install https://bitbucket.org/edge-team-leat/microai_public/get/6adfbcb347d3.zip\#subdirectory\=third_party/kerascnn2c_fixed

# %%
pip install https://bitbucket.org/edge-team-leat/microai_public/get/6adfbcb347d3.zip\#subdirectory\=third_party/kerascnn2c_fixed
# Out:
# Collecting https://bitbucket.org/edge-team-leat/microai_public/get/6adfbcb347d3.zip#subdirectory=third_party/kerascnn2c_fixed
#   Downloading https://bitbucket.org/edge-team-leat/microai_public/get/6adfbcb347d3.zip (1.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 4.5 MB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from kerascnn2c==1.0.0) (1.23.5)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from kerascnn2c==1.0.0) (3.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->kerascnn2c==1.0.0) (2.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import os
import librosa 
import kerascnn2c
from pathlib import Path
import tensorflow as tf
import copy
import librosa.display
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder,OneHotEncoder
from keras.models import Sequential
import tensorflow.keras.layers as layers
from keras.layers import Input, Conv1D, AvgPool1D, MaxPool1D, ZeroPadding1D, BatchNormalization, Flatten, Dense, Activation
from keras.utils.np_utils import to_categorical
from sklearn.metrics import confusion_matrix,classification_report,accuracy_score,f1_score
#train data creator

# %% [markdown]
# # 2. Create train_data

# %%
ID=[]
label=[]
# assign directory
directory = 'inputs/cats_dogs/train/'
 
# iterate over files in
# that directory

for folder in os.listdir(directory):                               #go into the directory
    for filename in os.listdir(directory+str(folder)):          #go in every class 
        f = os.path.join(directory+str(folder), filename)    #scan through every file in that class
        if os.path.isfile(f):
            ID.append(f.split('/')[-1])
            label.append(f.split('/')[-2])
            
train_data=pd.DataFrame()
train_data['ID']=ID
train_data['label']=label
print(train_data)
# Out:
#                      ID label
# 0             cat_1.wav   cat
# 1            cat_10.wav   cat
# 2           cat_100.wav   cat
# 3           cat_101.wav   cat
# 4           cat_102.wav   cat
# ..                  ...   ...
# 205  dog_barking_94.wav   dog
# 206  dog_barking_95.wav   dog
# 207  dog_barking_96.wav   dog
# 208  dog_barking_97.wav   dog
# 209  dog_barking_98.wav   dog
#
# [210 rows x 2 columns]

# %%
#HERE WE JUST SHOWING THE AMOUNT OF DATAS 86 DOGS & 125 CATS
plt.figure(figsize=(8,6),dpi=80)
sns.set_theme(style="darkgrid")
sns.countplot(x='label',data=train_data)
plt.title('counts: \n' +'dogs:'+str(train_data.label.value_counts()[1])+
          '\n cats:'+str(train_data.label.value_counts()[0]))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 7
#       4 sns.countplot(x='label',data=train_data)
#       5 plt.title('counts: \n' +'dogs:'+str(train_data.label.value_counts()[1])+
#       6           '\n cats:'+str(train_data.label.value_counts()[0]))
# ----> 7 plt.show()
#
# File /opt/conda/lib/python3.10/site-packages/matplotlib/pyplot.py:446, in show(*args, **kwargs)
#     402 """
#     403 Display all open figures.
#     404
#    (...)
#     443 explicitly there.
#     444 """
#     445 _warn_if_gui_out_of_main_thread()
# --> 446 return _get_backend_mod().show(*args, **kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/matplotlib_inline/backend_inline.py:99, in show(close, block)
#      96 # only call close('all') if any to close
#      97 # close triggers gc.collect, which can be slow
#      98 if close and Gcf.get_all_fig_managers():
# ---> 99     matplotlib.pyplot.close('all')
#
# File /opt/conda/lib/python3.10/site-packages/matplotlib/_api/__init__.py:226, in caching_module_getattr.<locals>.__getattr__(name)
#     224 if name in props:
#     225     return props[name].__get__(instance)
# --> 226 raise AttributeError(
#     227     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib' has no attribute 'pyplot'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File /opt/conda/lib/python3.10/site-packages/matplotlib_inline/backend_inline.py:99, in show(close, block)
#      96 # only call close('all') if any to close
#      97 # close triggers gc.collect, which can be slow
#      98 if close and Gcf.get_all_fig_managers():
# ---> 99     matplotlib.pyplot.close('all')
#
# File /opt/conda/lib/python3.10/site-packages/matplotlib/_api/__init__.py:226, in caching_module_getattr.<locals>.__getattr__(name)
#     224 if name in props:
#     225     return props[name].__get__(instance)
# --> 226 raise AttributeError(
#     227     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib' has no attribute 'pyplot'

# %% [markdown]
# # 3. Create test_data

# %%
ID=[]
label=[]
# assign directory
directory = 'inputs/cats_dogs/test/'
 
# iterate over files in
# that directory

for folder in os.listdir(directory):
    for filename in os.listdir(directory+str(folder)):
        f = os.path.join(directory+str(folder), filename)
        if os.path.isfile(f):
            ID.append(f.split('/')[-1])
            label.append(f.split('/')[-2])
            
# WE CHANGE LABELS NAMES FROM TEST TO DOG            
for i in range(len(label)):
    if(label[i]=='test'):
        label[i]='dogs'
        
test_data=pd.DataFrame()
test_data['ID']=ID
test_data['label']=label
print(test_data)
# Out:
#                     ID label
# 0          cat_110.wav  cats
# 1          cat_112.wav  cats
# 2          cat_115.wav  cats
# 3          cat_126.wav  cats
# 4          cat_129.wav  cats
# ..                 ...   ...
# 62  dog_barking_89.wav  dogs
# 63   dog_barking_9.wav  dogs
# 64  dog_barking_90.wav  dogs
# 65  dog_barking_91.wav  dogs
# 66  dog_barking_99.wav  dogs
#
# [67 rows x 2 columns]

# %% [markdown]
# # 4. Feature extraction of audio files using MFCCs

# %% [markdown]
# This function will access the audio files directly from the dataset and automatically store the features for each file in train set

# %% [markdown]
# In librosa.load function if we dont write sr=None, it will upsample every audio file to 22Khz which we dont want here.

# %% [markdown]
# We are using 100 Mel freq cepstrum coeff. for each audio file.

# %%
def extract_features(directory):
    features=[]
    ID=[]
    for folder in os.listdir(directory):
        for filename in os.listdir(directory+str(folder)):
            f = os.path.join(directory+str(folder), filename)
            
            if os.path.isfile(f):
                y,sr=librosa.load(f, res_type='kaiser_fast',sr=None)
                mfccs = np.mean(librosa.feature.mfcc(y=y, sr=sr, n_mfcc=100).T, axis=0)
    
                features.append(mfccs)
                ID.append(f.split('/')[-1])
    return [ID, features]

# %% [markdown]
# call on train data set

# %%
ID, features_train=extract_features('inputs/cats_dogs/train/')
ID,features_test=extract_features('inputs/cats_dogs/test/')

# %%
X_train=np.array(features_train)
X_test=np.array(features_test)
Y_train=train_data.label
Y_test=test_data.label

le=LabelEncoder()

temp=le.fit_transform(Y_train)
Y_train=temp.reshape(-1,1)

temp=le.fit_transform(Y_test)
Y_test=temp.reshape(-1,1)

model=tf.keras.Sequential()
model.add(layers.Input(shape=(100, 1)))
model.add(layers.MaxPool1D(pool_size=4, strides=3, padding='valid'))
model.add(layers.Conv1D(filters=64, kernel_size=8, activation='relu'))
model.add(layers.Flatten())
model.add(layers.Dense(units=1))
model.add(layers.Dense(1,activation='sigmoid'))



model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

hist=model.fit(X_train,Y_train,epochs=100)



model.save('cat_dogs.h5')

model = tf.keras.Model(model.input, model.layers[-2].output, name=model.name)

res = kerascnn2c.Converter(output_path=Path('gsc_output_fixed'),
                           fixed_point=9, # Number of bits for the fractional part, Q7.9 format
                           number_type='int16_t', # Data type for weights/activations (16 bits quantization)
                           long_number_type='int32_t', # Data type for intermediate results
                           number_min=-(2**15), # Minimum value for 16-bit signed integers
                           number_max=(2**15)-1 # Maximum value for 16-bit signed integers
                          ).convert_model(copy.deepcopy(model))
with open('gsc_model_fixed.h', 'w') as f:
    f.write(res)
# Out:
# Epoch 1/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6614 - accuracy: 0.6476
# Epoch 2/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6245 - accuracy: 0.7429
# Epoch 3/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5907 - accuracy: 0.8238
# Epoch 4/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5540 - accuracy: 0.8333
# Epoch 5/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.5173 - accuracy: 0.8333
# Epoch 6/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4827 - accuracy: 0.8238
# Epoch 7/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4551 - accuracy: 0.8238
# Epoch 8/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4278 - accuracy: 0.8381
# Epoch 9/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.4093 - accuracy: 0.8429
# Epoch 10/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3940 - accuracy: 0.8524
# Epoch 11/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3822 - accuracy: 0.8571
# Epoch 12/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3699 - accuracy: 0.8619
# Epoch 13/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3618 - accuracy: 0.8667
# Epoch 14/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3549 - accuracy: 0.8667
# Epoch 15/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3463 - accuracy: 0.8714
# Epoch 16/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3398 - accuracy: 0.8810
# Epoch 17/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3333 - accuracy: 0.8857
# Epoch 18/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3282 - accuracy: 0.8762
# Epoch 19/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3250 - accuracy: 0.8810
# Epoch 20/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.3169 - accuracy: 0.8857
# Epoch 21/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3176 - accuracy: 0.8905
# Epoch 22/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3095 - accuracy: 0.8857
# Epoch 23/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3006 - accuracy: 0.8857
# Epoch 24/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2954 - accuracy: 0.8905
# Epoch 25/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2907 - accuracy: 0.8905
# Epoch 26/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2867 - accuracy: 0.8905
# Epoch 27/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2822 - accuracy: 0.8905
# Epoch 28/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2773 - accuracy: 0.8952
# Epoch 29/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2727 - accuracy: 0.8905
# Epoch 30/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2666 - accuracy: 0.9000
# Epoch 31/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2644 - accuracy: 0.8952
# Epoch 32/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.2604 - accuracy: 0.8952
# Epoch 33/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2540 - accuracy: 0.9048
# Epoch 34/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2531 - accuracy: 0.9048
# Epoch 35/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2461 - accuracy: 0.9048
# Epoch 36/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2440 - accuracy: 0.9095
# Epoch 37/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2392 - accuracy: 0.9048
# Epoch 38/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2354 - accuracy: 0.9048
# Epoch 39/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2312 - accuracy: 0.9048
# Epoch 40/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2284 - accuracy: 0.9143
# Epoch 41/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2250 - accuracy: 0.9143
# Epoch 42/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2221 - accuracy: 0.9095
# Epoch 43/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2185 - accuracy: 0.9095
# Epoch 44/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2146 - accuracy: 0.9190
# Epoch 45/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2123 - accuracy: 0.9190
# Epoch 46/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2099 - accuracy: 0.9190
# Epoch 47/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2081 - accuracy: 0.9238
# Epoch 48/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2021 - accuracy: 0.9286
# Epoch 49/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1992 - accuracy: 0.9286
# Epoch 50/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1960 - accuracy: 0.9286
# Epoch 51/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1925 - accuracy: 0.9286
# Epoch 52/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1907 - accuracy: 0.9333
# Epoch 53/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1884 - accuracy: 0.9333
# Epoch 54/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1853 - accuracy: 0.9333
# Epoch 55/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1813 - accuracy: 0.9333
# Epoch 56/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1770 - accuracy: 0.9333
# Epoch 57/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1751 - accuracy: 0.9333
# Epoch 58/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1725 - accuracy: 0.9333
# Epoch 59/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1707 - accuracy: 0.9381
# Epoch 60/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1681 - accuracy: 0.9381
# Epoch 61/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1645 - accuracy: 0.9381
# Epoch 62/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1619 - accuracy: 0.9381
# Epoch 63/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1585 - accuracy: 0.9429
# Epoch 64/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.1560 - accuracy: 0.9429
# Epoch 65/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1544 - accuracy: 0.9476
# Epoch 66/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1519 - accuracy: 0.9429
# Epoch 67/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1538 - accuracy: 0.9429
# Epoch 68/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1463 - accuracy: 0.9476
# Epoch 69/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1438 - accuracy: 0.9429
# Epoch 70/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1403 - accuracy: 0.9476
# Epoch 71/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1378 - accuracy: 0.9476
# Epoch 72/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1353 - accuracy: 0.9524
# Epoch 73/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1336 - accuracy: 0.9476
# Epoch 74/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1306 - accuracy: 0.9476
# Epoch 75/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1271 - accuracy: 0.9476
# Epoch 76/100
# 7/7 [==============================] - 0s 4ms/step - loss: 0.1273 - accuracy: 0.9476
# Epoch 77/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1235 - accuracy: 0.9524
# Epoch 78/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1191 - accuracy: 0.9476
# Epoch 79/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1266 - accuracy: 0.9476
# Epoch 80/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1190 - accuracy: 0.9619
# Epoch 81/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1160 - accuracy: 0.9571
# Epoch 82/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1136 - accuracy: 0.9571
# Epoch 83/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1087 - accuracy: 0.9619
# Epoch 84/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1075 - accuracy: 0.9667
# Epoch 85/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1060 - accuracy: 0.9571
# Epoch 86/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1070 - accuracy: 0.9667
# Epoch 87/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1008 - accuracy: 0.9667
# Epoch 88/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1000 - accuracy: 0.9619
# Epoch 89/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0994 - accuracy: 0.9714
# Epoch 90/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0961 - accuracy: 0.9667
# Epoch 91/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0935 - accuracy: 0.9667
# Epoch 92/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0946 - accuracy: 0.9762
# Epoch 93/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0878 - accuracy: 0.9714
# Epoch 94/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0892 - accuracy: 0.9714
# Epoch 95/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0848 - accuracy: 0.9714
# Epoch 96/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0841 - accuracy: 0.9762
# Epoch 97/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0814 - accuracy: 0.9714
# Epoch 98/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0796 - accuracy: 0.9714
# Epoch 99/100
# 7/7 [==============================] - 0s 3ms/step - loss: 0.0787 - accuracy: 0.9714
# Epoch 100/100
# 7/7 [==============================] - 0s 2ms/step - loss: 0.0767 - accuracy: 0.9762
# Keras weights file (<HDF5 file "variables.h5" (mode r+)>) saving:
# ...layers
# ......conv1d
# .........vars
# ............0
# ............1
# ......dense
# .........vars
# ............0
# ............1
# ......flatten
# .........vars
# ......input_layer
# .........vars
# ......max_pooling1d
# .........vars
# ...vars
# Keras model archive saving:
# File Name                                             Modified             Size
# metadata.json                                  2023-04-30 18:47:44           64
# config.json                                    2023-04-30 18:47:44         2035
# variables.h5                                   2023-04-30 18:47:44        24040
# Keras model archive loading:
# File Name                                             Modified             Size
# metadata.json                                  2023-04-30 18:47:44           64
# config.json                                    2023-04-30 18:47:44         2035
# variables.h5                                   2023-04-30 18:47:44        24040
# Keras weights file (<HDF5 file "variables.h5" (mode r)>) loading:
# ...layers
# ......conv1d
# .........vars
# ............0
# ............1
# ......dense
# .........vars
# ............0
# ............1
# ......flatten
# .........vars
# ......input_layer
# .........vars
# ......max_pooling1d
# .........vars
# ...vars
# ———————————————————————————————————————————————————————————————————————————————————————————————————————
# Inputs                           | Layer                            | Outputs
# ———————————————————————————————————————————————————————————————————————————————————————————————————————
#                                  | input_10                         | max_pooling1d_4
# -------------------------------------------------------------------------------------------------------
# input_10                         | max_pooling1d_4                  | conv1d_3
# -------------------------------------------------------------------------------------------------------
# max_pooling1d_4                  | conv1d_3                         | flatten_7
# -------------------------------------------------------------------------------------------------------
# conv1d_3                         | flatten_7                        | dense_26
# -------------------------------------------------------------------------------------------------------
# flatten_7                        | dense_26                         |
# -------------------------------------------------------------------------------------------------------
#
# After optimization:
# ———————————————————————————————————————————————————————————————————————————————————————————————————————
# Inputs                           | Layer                            | Outputs
# ———————————————————————————————————————————————————————————————————————————————————————————————————————
#                                  | input_10                         | max_pooling1d_4
# -------------------------------------------------------------------------------------------------------
# input_10                         | max_pooling1d_4                  | conv1d_3
# -------------------------------------------------------------------------------------------------------
# max_pooling1d_4                  | conv1d_3                         | flatten_7
# -------------------------------------------------------------------------------------------------------
# conv1d_3                         | flatten_7                        | dense_26
# -------------------------------------------------------------------------------------------------------
# flatten_7                        | dense_26                         |
# -------------------------------------------------------------------------------------------------------

# %%
X_train[0].shape
# Out:
# (100,)

# %%
# !g++ -Wall -Wextra -pedantic -Ofast -o gsc_fixed -Igsc_output_fixed/ gsc_output_fixed/model.c main.cpp
# Out:
# gsc_output_fixed/model.c: In function ‘void cnn(const number_t (*)[100], number_t*)’:
# gsc_output_fixed/model.c:68:18: warning: left operand of comma operator has no effect [-Wunused-value]
#    68 |     activations2.conv1d_3_output,
#       |     ~~~~~~~~~~~~~^~~~~~~~~~~~~~~

# %%
# !./gsc_fixed x_test_gsc_250.csv y_test_gsc_250.csv
# Out:
# Error opening "x_test_gsc_250.csv": No such file or directory

# %%
Y_pred=model.predict(X_test)
Y_pred=(Y_pred>0.5)*1
print(classification_report(Y_test,Y_pred))
# Out:
# 3/3 [==============================] - 0s 2ms/step
#               precision    recall  f1-score   support
#
#            0       0.89      0.87      0.88        39
#            1       0.83      0.86      0.84        28
#
#     accuracy                           0.87        67
#    macro avg       0.86      0.86      0.86        67
# weighted avg       0.87      0.87      0.87        67

# %%
plt.figure(figsize=(10,8),dpi=80)
sns.heatmap(confusion_matrix(Y_test,Y_pred),annot=True,cmap='Blues')
plt.title('1 signifies dog sounds and 0 signifies cat sounds \n'+'Accuracy:'+str(accuracy_score(Y_test,Y_pred)))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[51], line 2
#       1 plt.figure(figsize=(10,8),dpi=80)
# ----> 2 sns.heatmap(confusion_matrix(Y_test,Y_pred),annot=True,cmap='Blues')
#       3 plt.title('1 signifies dog sounds and 0 signifies cat sounds \n'+'Accuracy:'+str(accuracy_score(Y_test,Y_pred)))
#       4 plt.show()
#
# File /opt/conda/lib/python3.10/site-packages/seaborn/matrix.py:459, in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     457 if square:
#     458     ax.set_aspect("equal")
# --> 459 plotter.plot(ax, cbar_ax, kwargs)
#     460 return ax
#
# File /opt/conda/lib/python3.10/site-packages/seaborn/matrix.py:316, in _HeatMapper.plot(self, ax, cax, kws)
#     314 # Possibly add a colorbar
#     315 if self.cbar:
# --> 316     cb = ax.figure.colorbar(mesh, cax, ax, **self.cbar_kws)
#     317     cb.outline.set_linewidth(0)
#     318     # If rasterized is passed to pcolormesh, also rasterize the
#     319     # colorbar to avoid white lines on the PDF rendering
#
# File /opt/conda/lib/python3.10/site-packages/matplotlib/figure.py:1279, in FigureBase.colorbar(self, mappable, cax, ax, use_gridspec, **kwargs)
#    1276 current_ax = self.gca()
#    1277 userax = False
#    1278 if (use_gridspec
# -> 1279         and isinstance(ax, mpl.axes._base._AxesBase)
#    1280         and ax.get_subplotspec()):
#    1281     cax, kwargs = cbar.make_axes_gridspec(ax, **kwargs)
#    1282 else:
#
# File /opt/conda/lib/python3.10/site-packages/matplotlib/_api/__init__.py:226, in caching_module_getattr.<locals>.__getattr__(name)
#     224 if name in props:
#     225     return props[name].__get__(instance)
# --> 226 raise AttributeError(
#     227     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib' has no attribute 'axes'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File /opt/conda/lib/python3.10/site-packages/matplotlib_inline/backend_inline.py:99, in show(close, block)
#      96 # only call close('all') if any to close
#      97 # close triggers gc.collect, which can be slow
#      98 if close and Gcf.get_all_fig_managers():
# ---> 99     matplotlib.pyplot.close('all')
#
# File /opt/conda/lib/python3.10/site-packages/matplotlib/_api/__init__.py:226, in caching_module_getattr.<locals>.__getattr__(name)
#     224 if name in props:
#     225     return props[name].__get__(instance)
# --> 226 raise AttributeError(
#     227     f"module {cls.__module__!r} has no attribute {name!r}")
#
# AttributeError: module 'matplotlib' has no attribute 'pyplot'
